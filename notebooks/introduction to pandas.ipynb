# %%
import pandas as pd

# %%
# 2 main data types
#series - 1 dimensional
series = pd.Series(["BMW", "Toyota", "BYD"])
series
# Out:
# 0       BMW
# 1    Toyota
# 2       BYD
# dtype: str

# %%
colors = pd.Series(["Blue", "Red", "White"])
colors
# Out:
# 0     Blue
# 1      Red
# 2    White
# dtype: str

# %%
# dataFrames- 2 dimensional datatypes
car_data = pd.DataFrame({'Car Make':series, "Color": colors})
car_data
# Out:
#   Car Make  Color
# 0      BMW   Blue
# 1   Toyota    Red
# 2      BYD  White

# %%
# rather than creating dataframe from scrach we usually import them from data
car_sales  = pd.read_csv('../data/raw/car-sales.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.to_csv('../data/exported/exported-car-sales-from-recap.csv',index = False )

# %%
exported_car_sales = pd.read_csv("../data/exported/exported-car-sales-from-recap.csv")
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Descirbe data

# %%
#attribute - infos about the car_sales data frame
car_sales.dtypes

#function - take action, perform some steps
# car_sales.to_csv()
# Out:
# Make               str
# Colour             str
# Odometer (KM)    int64
# Doors            int64
# Price              str
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='str')

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     str
#  1   Colour         10 non-null     str
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     str
# dtypes: int64(2), str(3)
# memory usage: 532.0 bytes

# %%
car_prices = pd.Series([3000,1500,111250])
car_prices.mean()
# Out:
# np.float64(38583.333333333336)

# %%
car_sales.dtypes
# Out:
# Make               str
# Colour             str
# Odometer (KM)    int64
# Doors            int64
# Price              str
# dtype: object

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Odometer (KM)"].sum()
# Out:
# np.int64(786014)

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# ### Viewing and selecting data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_sales.tail(2)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# loc and iloc
# iloc = refers to position and loc refers to index position
animals = pd.Series(["cat","dog","bird","pandas"], index=[0,3,9,8])
animals
# Out:
# 0       cat
# 3       dog
# 9      bird
# 8    pandas
# dtype: str

# %%
animals.iloc[3]
# Out:
# 'pandas'

# %%
animals.loc[8]
# Out:
# 'pandas'

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals
# Out:
# 0       cat
# 3       dog
# 9      bird
# 8    pandas
# dtype: str

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: str

# %%
animals.loc[:3]
# Out:
# 0    cat
# 3    dog
# dtype: str

# %%
animals.iloc[1:3]
# Out:
# 3     dog
# 9    bird
# dtype: str

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: str

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: str

# %%
car_sales[car_sales.Make == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"] >= 94000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00
# 5  Toyota  Green          99213      4  $4,500.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_sales.Make, car_sales.Doors)
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Groupby
car_sales.groupby(["Make"]).mean(numeric_only = True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales.groupby("Make")[["Odometer (KM)", "Doors"]].mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.Doors.plot()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <Axes: >

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
car_sales["Price"].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 car_sales["Price"].plot()
#
# File ~/Projects/sample-project/env/lib/python3.14/site-packages/pandas/plotting/_core.py:1185, in PlotAccessor.__call__(self, *args, **kwargs)
#    1182             label_name = label_kw or data.columns
#    1183             data.columns = label_name
# -> 1185 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/Projects/sample-project/env/lib/python3.14/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plt.draw_if_interactive()
#      73 return plot_obj.result
#
# ...

# %%
car_sales["Price"] = (
    car_sales["Price"]
    .astype(str)  # Ensure all values are strings
    .str.replace(r'[\$,\.]', '', regex=True)  # Use raw string + regex=True
    .astype(int)  # Convert cleaned strings to integers
)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.Price
# Out:
# 0     $4,000.00
# 1     $5,000.00
# 2     $7,000.00
# 3    $22,000.00
# 4     $3,500.00
# 5     $4,500.00
# 6     $7,500.00
# 7     $7,000.00
# 8     $6,250.00
# 9     $9,700.00
# Name: Price, dtype: str

# %%
correct_dec = pd.DataFrame({"price":["$4000.00", "$5000.00"]})

# %%
correct_dec
# Out:
#       price
# 0  $4000.00
# 1  $5000.00

# %%
correct_dec.price= (
    correct_dec.price
    .astype(str)
    .str.replace(r'[\$,]', '', regex=True)
    .astype(float)
    .astype(int)
)

# %%
correct_dec
# Out:
#    price
# 0   4000
# 1   5000

# %%
correct_dec.price.plot()
# Out:
# <Axes: >

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Manipulating Data

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.Make.str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: str

# %%
car_sales.Make = car_sales.Make.str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  toyota  White         150043      4   $4,000.00
# 1   honda    Red          87899      4   $5,000.00
# 2  toyota   Blue          32549      3   $7,000.00
# 3     bmw  Black          11179      5  $22,000.00
# 4  nissan  White         213095      4   $3,500.00
# 5  toyota  Green          99213      4   $4,500.00
# 6   honda   Blue          45698      4   $7,500.00
# 7   honda   Blue          54738      4   $7,000.00
# 8  toyota  White          60000      4   $6,250.00
# 9  nissan  White          31600      4   $9,700.00

# %%
car_sales_missing_data = pd.read_csv("../data/raw/car-sales-missing-data.csv")

# %%
car_sales_missing_data
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# car_sales_missing_data.Odometer.fillna(car_sales_missing_data.Odometer.mean(),inplace= True)
# car_sales_missing_data
car_sales_missing_data['Odometer'] = (
    car_sales_missing_data['Odometer']
    .fillna(car_sales_missing_data['Odometer'].mean())
)
car_sales_missing_data
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing_data
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing_data.dropna(inplace=True)

# %%
car_sales_missing_data
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing_data.to_csv("../data/processed/car_sales_missing_dropped.csv",index=False)

# %%
car_sales_missing_data
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  toyota  White         150043      4   $4,000.00
# 1   honda    Red          87899      4   $5,000.00
# 2  toyota   Blue          32549      3   $7,000.00
# 3     bmw  Black          11179      5  $22,000.00
# 4  nissan  White         213095      4   $3,500.00
# 5  toyota  Green          99213      4   $4,500.00
# 6   honda   Blue          45698      4   $7,500.00
# 7   honda   Blue          54738      4   $7,000.00
# 8  toyota  White          60000      4   $6,250.00
# 9  nissan  White          31600      4   $9,700.00

# %%
#Column from series
seat_column = pd.Series([5,5,5,5,5])

# New Column called Seats
car_sales["Seat"] = seat_column

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seat
# 0  toyota  White         150043      4   $4,000.00   5.0
# 1   honda    Red          87899      4   $5,000.00   5.0
# 2  toyota   Blue          32549      3   $7,000.00   5.0
# 3     bmw  Black          11179      5  $22,000.00   5.0
# 4  nissan  White         213095      4   $3,500.00   5.0
# 5  toyota  Green          99213      4   $4,500.00   NaN
# 6   honda   Blue          45698      4   $7,500.00   NaN
# 7   honda   Blue          54738      4   $7,000.00   NaN
# 8  toyota  White          60000      4   $6,250.00   NaN
# 9  nissan  White          31600      4   $9,700.00   NaN

# %%
car_sales.Seat = car_sales.Seat.fillna(5)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seat
# 0  toyota  White         150043      4   $4,000.00   5.0
# 1   honda    Red          87899      4   $5,000.00   5.0
# 2  toyota   Blue          32549      3   $7,000.00   5.0
# 3     bmw  Black          11179      5  $22,000.00   5.0
# 4  nissan  White         213095      4   $3,500.00   5.0
# 5  toyota  Green          99213      4   $4,500.00   5.0
# 6   honda   Blue          45698      4   $7,500.00   5.0
# 7   honda   Blue          54738      4   $7,000.00   5.0
# 8  toyota  White          60000      4   $6,250.00   5.0
# 9  nissan  White          31600      4   $9,700.00   5.0

# %%
fuel_economy = [7.2, 3.9,8.6,5.2,6.9,7.6,14.2,2.9,7.6,3.2]
car_sales["Fuel Per 100 KM"] = fuel_economy

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seat  Fuel Per 100 KM
# 0  toyota  White         150043      4   $4,000.00   5.0              7.2
# 1   honda    Red          87899      4   $5,000.00   5.0              3.9
# 2  toyota   Blue          32549      3   $7,000.00   5.0              8.6
# 3     bmw  Black          11179      5  $22,000.00   5.0              5.2
# 4  nissan  White         213095      4   $3,500.00   5.0              6.9
# 5  toyota  Green          99213      4   $4,500.00   5.0              7.6
# 6   honda   Blue          45698      4   $7,500.00   5.0             14.2
# 7   honda   Blue          54738      4   $7,000.00   5.0              2.9
# 8  toyota  White          60000      4   $6,250.00   5.0              7.6
# 9  nissan  White          31600      4   $9,700.00   5.0              3.2

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seat  Fuel Per 100 KM
# 0  toyota  White         150043      4   $4,000.00   5.0              7.2
# 1   honda    Red          87899      4   $5,000.00   5.0              3.9
# 2  toyota   Blue          32549      3   $7,000.00   5.0              8.6
# 3     bmw  Black          11179      5  $22,000.00   5.0              5.2
# 4  nissan  White         213095      4   $3,500.00   5.0              6.9
# 5  toyota  Green          99213      4   $4,500.00   5.0              7.6
# 6   honda   Blue          45698      4   $7,500.00   5.0             14.2
# 7   honda   Blue          54738      4   $7,000.00   5.0              2.9
# 8  toyota  White          60000      4   $6,250.00   5.0              7.6
# 9  nissan  White          31600      4   $9,700.00   5.0              3.2

# %%
car_sales["Total Fule Used(L)"] = car_sales["Odometer (KM)"]* car_sales["Fuel Per 100 KM"] / 100
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seat  Fuel Per 100 KM  \
# 0  toyota  White         150043      4   $4,000.00   5.0              7.2
# 1   honda    Red          87899      4   $5,000.00   5.0              3.9
# 2  toyota   Blue          32549      3   $7,000.00   5.0              8.6
# 3     bmw  Black          11179      5  $22,000.00   5.0              5.2
# 4  nissan  White         213095      4   $3,500.00   5.0              6.9
# 5  toyota  Green          99213      4   $4,500.00   5.0              7.6
# 6   honda   Blue          45698      4   $7,500.00   5.0             14.2
# 7   honda   Blue          54738      4   $7,000.00   5.0              2.9
# 8  toyota  White          60000      4   $6,250.00   5.0              7.6
# 9  nissan  White          31600      4   $9,700.00   5.0              3.2
#
#    Total Fule Used(L)
# 0           10803.096
# 1            3428.061
# 2            2799.214
# 3             581.308
# 4           14703.555
# ...

# %%
car_sales ["Number of wheels"] = 4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seat  Fuel Per 100 KM  \
# 0  toyota  White         150043      4   $4,000.00   5.0              7.2
# 1   honda    Red          87899      4   $5,000.00   5.0              3.9
# 2  toyota   Blue          32549      3   $7,000.00   5.0              8.6
# 3     bmw  Black          11179      5  $22,000.00   5.0              5.2
# 4  nissan  White         213095      4   $3,500.00   5.0              6.9
# 5  toyota  Green          99213      4   $4,500.00   5.0              7.6
# 6   honda   Blue          45698      4   $7,500.00   5.0             14.2
# 7   honda   Blue          54738      4   $7,000.00   5.0              2.9
# 8  toyota  White          60000      4   $6,250.00   5.0              7.6
# 9  nissan  White          31600      4   $9,700.00   5.0              3.2
#
#    Total Fule Used(L)  Number of wheels
# 0           10803.096                 4
# 1            3428.061                 4
# ...

# %%
car_sales["Passed road saftey"] = True

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seat  Fuel Per 100 KM  \
# 0  toyota  White         150043      4   $4,000.00   5.0              7.2
# 1   honda    Red          87899      4   $5,000.00   5.0              3.9
# 2  toyota   Blue          32549      3   $7,000.00   5.0              8.6
# 3     bmw  Black          11179      5  $22,000.00   5.0              5.2
# 4  nissan  White         213095      4   $3,500.00   5.0              6.9
# 5  toyota  Green          99213      4   $4,500.00   5.0              7.6
# 6   honda   Blue          45698      4   $7,500.00   5.0             14.2
# 7   honda   Blue          54738      4   $7,000.00   5.0              2.9
# 8  toyota  White          60000      4   $6,250.00   5.0              7.6
# 9  nissan  White          31600      4   $9,700.00   5.0              3.2
#
#    Total Fule Used(L)  Number of wheels  Passed road saftey
# 0           10803.096                 4                True
# ...

# %%
car_sales.dtypes
# Out:
# Make                      str
# Colour                    str
# Odometer (KM)           int64
# Doors                   int64
# Price                     str
# Seat                  float64
# Fuel Per 100 KM       float64
# Total Fule Used(L)    float64
# Number of wheels        int64
# Passed road saftey       bool
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seat  Fuel Per 100 KM  \
# 0  toyota  White         150043      4   $4,000.00   5.0              7.2
# 1   honda    Red          87899      4   $5,000.00   5.0              3.9
# 2  toyota   Blue          32549      3   $7,000.00   5.0              8.6
# 3     bmw  Black          11179      5  $22,000.00   5.0              5.2
# 4  nissan  White         213095      4   $3,500.00   5.0              6.9
# 5  toyota  Green          99213      4   $4,500.00   5.0              7.6
# 6   honda   Blue          45698      4   $7,500.00   5.0             14.2
# 7   honda   Blue          54738      4   $7,000.00   5.0              2.9
# 8  toyota  White          60000      4   $6,250.00   5.0              7.6
# 9  nissan  White          31600      4   $9,700.00   5.0              3.2
#
#    Total Fule Used(L)  Number of wheels  Passed road saftey
# 0           10803.096                 4                True
# ...

# %%
car_sales.sample(frac=1)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seat  Fuel Per 100 KM  \
# 2  toyota   Blue          32549      3   $7,000.00   5.0              8.6
# 8  toyota  White          60000      4   $6,250.00   5.0              7.6
# 9  nissan  White          31600      4   $9,700.00   5.0              3.2
# 4  nissan  White         213095      4   $3,500.00   5.0              6.9
# 0  toyota  White         150043      4   $4,000.00   5.0              7.2
# 5  toyota  Green          99213      4   $4,500.00   5.0              7.6
# 1   honda    Red          87899      4   $5,000.00   5.0              3.9
# 3     bmw  Black          11179      5  $22,000.00   5.0              5.2
# 7   honda   Blue          54738      4   $7,000.00   5.0              2.9
# 6   honda   Blue          45698      4   $7,500.00   5.0             14.2
#
#    Total Fule Used(L)  Number of wheels  Passed road saftey
# 2            2799.214                 4                True
# ...

# %%
car_sales_shuffled = car_sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seat  Fuel Per 100 KM  \
# 1   honda    Red          87899      4   $5,000.00   5.0              3.9
# 9  nissan  White          31600      4   $9,700.00   5.0              3.2
# 3     bmw  Black          11179      5  $22,000.00   5.0              5.2
# 2  toyota   Blue          32549      3   $7,000.00   5.0              8.6
# 0  toyota  White         150043      4   $4,000.00   5.0              7.2
# 6   honda   Blue          45698      4   $7,500.00   5.0             14.2
# 8  toyota  White          60000      4   $6,250.00   5.0              7.6
# 5  toyota  Green          99213      4   $4,500.00   5.0              7.6
# 7   honda   Blue          54738      4   $7,000.00   5.0              2.9
# 4  nissan  White         213095      4   $3,500.00   5.0              6.9
#
#    Total Fule Used(L)  Number of wheels  Passed road saftey
# 1            3428.061                 4                True
# ...

# %%
car_sales_shuffled.sample(frac = 0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Seat  Fuel Per 100 KM  \
# 7   honda   Blue          54738      4  $7,000.00   5.0              2.9
# 4  nissan  White         213095      4  $3,500.00   5.0              6.9
#
#    Total Fule Used(L)  Number of wheels  Passed road saftey
# 7            1587.402                 4                True
# 4           14703.555                 4                True

# %%
car_sales_shuffled.reset_index(inplace=True, drop=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seat  Fuel Per 100 KM  \
# 0  toyota  White         150043      4   $4,000.00   5.0              7.2
# 1   honda    Red          87899      4   $5,000.00   5.0              3.9
# 2  toyota   Blue          32549      3   $7,000.00   5.0              8.6
# 3     bmw  Black          11179      5  $22,000.00   5.0              5.2
# 4  nissan  White         213095      4   $3,500.00   5.0              6.9
# 5  toyota  Green          99213      4   $4,500.00   5.0              7.6
# 6   honda   Blue          45698      4   $7,500.00   5.0             14.2
# 7   honda   Blue          54738      4   $7,000.00   5.0              2.9
# 8  toyota  White          60000      4   $6,250.00   5.0              7.6
# 9  nissan  White          31600      4   $9,700.00   5.0              3.2
#
#    Total Fule Used(L)  Number of wheels  Passed road saftey
# 0           10803.096                 4                True
# ...

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seat  Fuel Per 100 KM  \
# 0   honda    Red          87899      4   $5,000.00   5.0              3.9
# 1  nissan  White          31600      4   $9,700.00   5.0              3.2
# 2     bmw  Black          11179      5  $22,000.00   5.0              5.2
# 3  toyota   Blue          32549      3   $7,000.00   5.0              8.6
# 4  toyota  White         150043      4   $4,000.00   5.0              7.2
# 5   honda   Blue          45698      4   $7,500.00   5.0             14.2
# 6  toyota  White          60000      4   $6,250.00   5.0              7.6
# 7  toyota  Green          99213      4   $4,500.00   5.0              7.6
# 8   honda   Blue          54738      4   $7,000.00   5.0              2.9
# 9  nissan  White         213095      4   $3,500.00   5.0              6.9
#
#    Total Fule Used(L)  Number of wheels  Passed road saftey
# 0            3428.061                 4                True
# ...

# %% [markdown]
# ## Applying a function on column

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x/1.6)
car_sales.rename(columns={"Odometer (KM)": "Odometer (Miles)"}, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (Miles)  Doors       Price  Seat  Fuel Per 100 KM  \
# 0  toyota  White         93776.875      4   $4,000.00   5.0              7.2
# 1   honda    Red         54936.875      4   $5,000.00   5.0              3.9
# 2  toyota   Blue         20343.125      3   $7,000.00   5.0              8.6
# 3     bmw  Black          6986.875      5  $22,000.00   5.0              5.2
# 4  nissan  White        133184.375      4   $3,500.00   5.0              6.9
# 5  toyota  Green         62008.125      4   $4,500.00   5.0              7.6
# 6   honda   Blue         28561.250      4   $7,500.00   5.0             14.2
# 7   honda   Blue         34211.250      4   $7,000.00   5.0              2.9
# 8  toyota  White         37500.000      4   $6,250.00   5.0              7.6
# 9  nissan  White         19750.000      4   $9,700.00   5.0              3.2
#
#    Total Fule Used(L)  Number of wheels  Passed road saftey
# 0           10803.096                 4                True
# ...
